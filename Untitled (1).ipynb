# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# Out:
# /home/chams/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# ## importing and preprocessing the data

# %%
data = pd.read_csv('StudentPerformanceFactors.csv')

# %%
data.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
print(f'Our data have {data.shape[0]} rows and {data.shape[1]} column')
# Out:
# Our data have 6607 rows and 20 column

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
data.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
data['Distance_from_Home'].value_counts()
# Out:
# Distance_from_Home
# Near        3884
# Moderate    1998
# Far          658
# Name: count, dtype: int64

# %% [raw]
# Since the missing data is only in columns of type 'object', and the dataset is large with a small amount of missing data,For now, we can drop the rows containing null values. after analysis the relation of these columns with other we can also use some desirable ml algo to predictthese value

# %%
df= data.dropna()
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
df.shape
# Out:
# (6378, 20)

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6378.000000  6378.000000  6378.000000      6378.000000
# mean       19.977109    80.020853     7.034964        75.066165
# std         5.985460    11.550723     1.468033        14.400389
# min         1.000000    60.000000     4.000000        50.000000
# 25%        16.000000    70.000000     6.000000        63.000000
# 50%        20.000000    80.000000     7.000000        75.000000
# 75%        24.000000    90.000000     8.000000        88.000000
# max        44.000000   100.000000    10.000000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6378.000000        6378.000000  6378.000000
# mean            1.495296           2.972719    67.252117
# std             1.233984           1.028926     3.914217
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
df.duplicated().sum() #no duplicate is found in the data set
# Out:
# 0

# %%
cat=[]
num=[]
for column in data.columns:
    if data[column].nunique()>10:
        num.append(column)
    else:
        cat.append(column)
        

print(f'numeric columns are {num}')
print(f'categorical columns are {cat}')
# Out:
# numeric columns are ['Hours_Studied', 'Attendance', 'Previous_Scores', 'Exam_Score']
# categorical columns are ['Parental_Involvement', 'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours', 'Motivation_Level', 'Internet_Access', 'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type', 'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities', 'Parental_Education_Level', 'Distance_from_Home', 'Gender']

# %% [markdown]
# # univariante analysis

# %% [markdown]
# ## numeric

# %%
num
# Out:
# ['Hours_Studied', 'Attendance', 'Previous_Scores', 'Exam_Score']

# %% [markdown]
# ### for exam_score

# %%
sns.kdeplot(df['Exam_Score'])
# Out:
# <Axes: xlabel='Exam_Score', ylabel='Density'>

# %%
df['Exam_Score'].skew()
# Out:
# 1.6658308149706298

# %%
df['Exam_Score'].describe()
# Out:
# count    6378.000000
# mean       67.252117
# std         3.914217
# min        55.000000
# 25%        65.000000
# 50%        67.000000
# 75%        69.000000
# max       101.000000
# Name: Exam_Score, dtype: float64

# %% [markdown]
# The data is skew toward the right also the mean is greather the the median

# %%
sns.boxplot(df['Exam_Score'])
# Out:
# <Axes: ylabel='Exam_Score'>

# %% [markdown]
# there are many outliner in the data set as we see in the above figure

# %%
Q1 = df['Exam_Score'].quantile(0.25)
Q3 = df['Exam_Score'].quantile(0.75)

# Step 2: Calculate the Interquartile Range (IQR)
IQR = Q3 - Q1
print(f'Q1={Q1}, Q3={Q3} and IQR={IQR}')
# Out:
# Q1=65.0, Q3=69.0 and IQR=4.0

# %% [markdown]
# exam score are very concentrated with a iqr of only 4

# %% [markdown]
# ### for previous score

# %%
sns.kdeplot(df['Previous_Scores'])
# Out:
# <Axes: xlabel='Previous_Scores', ylabel='Density'>

# %%
df['Previous_Scores'].skew()
# Out:
# -0.0013616826888904168

# %%
sns.boxplot(df['Previous_Scores'])
# Out:
# <Axes: ylabel='Previous_Scores'>

# %% [markdown]
# the previous score is nearlly symmetric with skew score almost 0 also there is no outliners

# %%
Q1 = df['Previous_Scores'].quantile(0.25)
Q3 = df['Previous_Scores'].quantile(0.75)

# Step 2: Calculate the Interquartile Range (IQR)
IQR = Q3 - Q1
print(f'Q1={Q1}, Q3={Q3} and IQR={IQR}')
# Out:
# Q1=63.0, Q3=88.0 and IQR=25.0

# %% [markdown]
# ### for Hours_Studied per week

# %% [markdown]
# the previous score is more spreadout with a higher iqr

# %%
sns.kdeplot(df['Hours_Studied'])
# Out:
# <Axes: xlabel='Hours_Studied', ylabel='Density'>

# %%
df['Hours_Studied'].skew()
# Out:
# 0.016224630345704642

# %%
df['Hours_Studied'].describe()
# Out:
# count    6378.000000
# mean       19.977109
# std         5.985460
# min         1.000000
# 25%        16.000000
# 50%        20.000000
# 75%        24.000000
# max        44.000000
# Name: Hours_Studied, dtype: float64

# %%
sns.boxplot(df['Hours_Studied'])
# Out:
# <Axes: ylabel='Hours_Studied'>

# %% [markdown]
# ### for attendance

# %%
sns.kdeplot(df['Attendance'])
# Out:
# <Axes: xlabel='Attendance', ylabel='Density'>

# %%
df['Attendance'].skew()
# Out:
# 0.005662718901984047

# %%
df['Attendance'].describe()
# Out:
# count    6378.000000
# mean       80.020853
# std        11.550723
# min        60.000000
# 25%        70.000000
# 50%        80.000000
# 75%        90.000000
# max       100.000000
# Name: Attendance, dtype: float64

# %%
sns.boxplot(df['Attendance'])
# Out:
# <Axes: ylabel='Attendance'>

# %% [markdown]
# ## categorical

# %%
cat
# Out:
# ['Parental_Involvement',
#  'Access_to_Resources',
#  'Extracurricular_Activities',
#  'Sleep_Hours',
#  'Motivation_Level',
#  'Internet_Access',
#  'Tutoring_Sessions',
#  'Family_Income',
#  'Teacher_Quality',
#  'School_Type',
#  'Peer_Influence',
#  'Physical_Activity',
#  'Learning_Disabilities',
#  'Parental_Education_Level',
#  'Distance_from_Home',
#  'Gender']

# %%
for i in cat:
    df[i].value_counts().plot(kind="pie",autopct="%1.2f%%")
    plt.title(i)
    plt.show()

# %%
for i in cat:
    df[i].value_counts().plot(kind="bar")
    plt.title(i)
    plt.show()

# %% [markdown]
# # Bivariante

# %% [markdown]
# ## numerical- numerical

# %%
num
# Out:
# ['Hours_Studied', 'Attendance', 'Previous_Scores', 'Exam_Score']

# %%
plt.scatter(df['Attendance'],df['Exam_Score'])

# %%
np.corrcoef(df['Attendance'],df['Exam_Score'])[0,1]
# Out:
# 0.5802585402382593

# %%
print(np.corrcoef(df['Previous_Scores'],df['Exam_Score'])[0,1])
plt.scatter(df['Previous_Scores'],df['Exam_Score'])
# Out:
# 0.1742830490031804

# %% [markdown]
# ## categorical and numerical

# %%
num,cat
# Out:
# (['Hours_Studied', 'Attendance', 'Previous_Scores', 'Exam_Score'],
#  ['Parental_Involvement',
#   'Access_to_Resources',
#   'Extracurricular_Activities',
#   'Sleep_Hours',
#   'Motivation_Level',
#   'Internet_Access',
#   'Tutoring_Sessions',
#   'Family_Income',
#   'Teacher_Quality',
#   'School_Type',
#   'Peer_Influence',
#   'Physical_Activity',
#   'Learning_Disabilities',
#   'Parental_Education_Level',
#   'Distance_from_Home',
#   'Gender'])

# %%
from sklearn.preprocessing import StandardScaler

# Select only the numeric columns
# numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

# Initialize the MinMaxScaler
scaler = StandardScaler()

# Fit and transform only the numeric columns
df[num] = scaler.fit_transform(df[num])
# Out:
# /tmp/ipykernel_28971/683518781.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[num] = scaler.fit_transform(df[num])

# %%
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0          0.505079    0.344520                  Low                High
# 1         -0.163260   -1.387109                  Low              Medium
# 2          0.672163    1.556661               Medium              Medium
# 3          1.507587    0.777428                  Low              Medium
# 4         -0.163260    1.037172               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602       0.839248   -0.954201                 High              Medium
# 6603       0.505079   -0.348131                 High              Medium
# 6604       0.003825    0.864009               Medium                 Low
# 6605      -1.667022    0.517683                 High                High
# 6606      -0.831598   -1.127364               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
cat
# Out:
# ['Parental_Involvement',
#  'Access_to_Resources',
#  'Extracurricular_Activities',
#  'Sleep_Hours',
#  'Motivation_Level',
#  'Internet_Access',
#  'Tutoring_Sessions',
#  'Family_Income',
#  'Teacher_Quality',
#  'School_Type',
#  'Peer_Influence',
#  'Physical_Activity',
#  'Learning_Disabilities',
#  'Parental_Education_Level',
#  'Distance_from_Home',
#  'Gender']

# %%
for i in cat:
    sns.barplot(data=df,x=i,y="Exam_Score")
    plt.show()

# %%
for i in cat:
    sns.barplot(data=df,x=i,y="Previous_Scores")
    plt.show()

# %%
pd.crosstab(df['School_Type'],data['Teacher_Quality'])
# Out:
# Teacher_Quality  High  Low  Medium
# School_Type
# Private           589  190    1165
# Public           1316  457    2661

# %% [markdown]
# # conclusion

# %% [raw]
# 1. previous marks are uniformly distributed while in exam mark most people perform similar with iqr of only 4 but there are many outliners in the exam
# 2.the corr between attendence and exam marks is 0.5802585402382593 showing that there is a positive impact of attending class
# 3(Parental_Involvement,Access_to_Resources,Extracurricular_Activities,Motivation_Level,Internet_Access,Family_Income,Teacher_Quality,Peer_Influence,Parental_Education_Level,Distance_from_Home) they have significant impact on marks.
# 4. on average female perform better than male
# 5. public school have lower performance than private school
# 6. those who have physical activity of around 6 and tutorial seasion of around 6 have better marks than other
# 7. there is an interesting fact that those who are having 4 hrs of sleep gives better result that students
